# %% [markdown]
# ## Setup notebook
# **First, set the notebook runtime to T4 GPU.**
# Steps derived from this article: https://mlabonne.github.io/blog/posts/Fine_Tune_Your_Own_Llama_2_Model_in_a_Colab_Notebook.html

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 70.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 51.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 40.7 MB/s eta 0:00:00

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    StoppingCriteria,
    StoppingCriteriaList,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %%
# The model that you want to train from the Hugging Face hub
model_name = "NousResearch/llama-2-7b-chat-hf"

# Fine-tuned model name
new_model = "llama-2-7b-finetuned"  # TODO - change this depending on finetuning task

# %%
################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

# %%
################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

# %%
################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule (constant a bit better than cosine)
lr_scheduler_type = "constant"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 25

# Log every X updates steps
logging_steps = 25

# %%
################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %% [markdown]
# ## Define prompt

# %%
prompt = "Provide an explanation on why this pun is funny."

# %% [markdown]
# ## Load data
#
# The following prompt template is used to format the training and inference inputs:
# - Training: https://huggingface.co/datasets/mlabonne/guanaco-llama2-1k
# - Inference: https://gpus.llm-utils.org/llama-2-prompt-template/

# %%
# Load dataset
import pandas as pd

filename_train_dataset = "data/train_explanations.csv"  # each row is an explanation; for training!
filename_test_dataset = "data/test_jokes.csv"  # each row is a joke; for inference!

train_dataset = load_dataset('csv', data_files=filename_train_dataset, split="train")
test_dataset = load_dataset('csv', data_files=filename_test_dataset, split="train")

df_train = pd.read_csv(filename_train_dataset)
df_test = pd.read_csv(filename_test_dataset)

df_train["model_train_input_text"] = df_train.apply(lambda x: "<s>[INST] <<SYS>>\n" + prompt + "\n<</SYS>>\n\n" + x["text"] + " [/INST] " + x["Natural language explanation"] + "</s>", axis=1)
df_test["model_inference_input_text"] = df_test.apply(lambda x: "<s>[INST] <<SYS>>\n" + prompt + "\n<</SYS>>\n\n" + x["text"] + " [/INST]", axis=1)

train_dataset = train_dataset.add_column(name="model_train_input_text", column=df_train["model_train_input_text"].to_list())
test_dataset = test_dataset.add_column(name="model_inference_input_text", column=df_test["model_inference_input_text"].to_list())

print(train_dataset)  # number of explanations; divide by 5 to get number of jokes
print(test_dataset)  # number of jokes; multiply by 5 to get number of explanations
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['ID', 'Annotator_ID', 'Funniness (1-5)', 'Is a Joke?', 'Joke keywords', 'Natural language explanation', 'Offensive/Inappropriate?', 'Understand the text?', 'text', 'model_train_input_text'],
#     num_rows: 2300
# })
# Dataset({
#     features: ['ID', 'text', 'Natural language explanation 1', 'Natural language explanation 2', 'Natural language explanation 3', 'Natural language explanation 4', 'Natural language explanation 5', 'model_inference_input_text'],
#     num_rows: 115
# })

# %% [markdown]
# ## Finetuning methods

# %%
from tqdm import tqdm

def generate_outputs(dataset, model, tokenizer, batch_size=24, max_new_tokens=500):
    """Generate outputs for each input in the dataset."""
    input_texts = [example["model_inference_input_text"] for example in dataset]
    output_texts = []

    for i in tqdm(list(range(0, len(input_texts), batch_size))):  # for each batch
        input_texts_batch = input_texts[i:min(i+batch_size,len(input_texts))]

        # Tokenize
        tokenize_result = tokenizer(input_texts_batch, return_tensors="pt", padding=True).to(model.device)

        # Generate outputs
        with torch.no_grad():
            outputs_batch = model.generate(**tokenize_result,
                                           max_new_tokens=max_new_tokens)

        # Decode outputs
        output_texts_batch = tokenizer.batch_decode(outputs_batch, skip_special_tokens=True)
        output_texts.extend(output_texts_batch)

    return output_texts

def print_joke_with_output(dataset, outputs, limit):
    for i, example in enumerate(dataset):
        if i == limit:
            break
        print("Pun:", example["text"])
        print("Output:", outputs[i])
        print()

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
from statistics import mean
import numpy as np

def get_sentence_embedding(sentence, model, tokenizer):
    """
    Get the sentence embedding for a given sentence.
    """
    input_ids = tokenizer.encode(sentence, return_tensors='pt')
    with torch.no_grad():
        output = model(input_ids)[0]
    sentence_embedding = torch.mean(output, dim=1).squeeze()
    return sentence_embedding.detach().cpu().numpy()

def calculate_cosine_similarity(dataset, outputs):
    """
    Calculate the cosine similarity between the prediction and ground truth for the entire dataset.
    """
    model_name = 'bert-base-uncased'
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    cosine_similarities = {"1": [], "2": [], "3": [], "4": [], "5": [], "mean": []}
    preds = []

    dataset = dataset.add_column(name="model_output_text", column=outputs)
    for example in tqdm(dataset):

        pred = example['model_output_text']
        if "[/INST]" in pred:
            idx = pred.index("[/INST]") + len("[/INST]")
            pred = pred[idx:]
        if "</s>" in pred:
            idx = pred.index("</s>")
            pred = pred[:idx]
        if len(pred) > 512:  # manual truncation
            pred = pred[:512]
        pred = pred[1:]  # remove newline or leading ']' character
        pred = pred.strip()  # remove leading or trailing whitespace
        preds.append(pred)

        pred_embedding = get_sentence_embedding(pred, model, tokenizer)

        cosine_similarities_example = []
        for i in range(5):
            groundtruth = example[f'Natural language explanation {i + 1}']
            groundtruth_embedding = get_sentence_embedding(groundtruth, model, tokenizer)

            cosine_sim = cosine_similarity([pred_embedding], [groundtruth_embedding])[0][0]
            cosine_similarities_example.append(cosine_sim)
            cosine_similarities[f"{i + 1}"].append(cosine_sim)

        cosine_similarities["mean"].append(mean(cosine_similarities_example))

    return cosine_similarities, preds

# %%
def evaluate_cosine_similarity(sims):
  print(f"Mean cosine similarity: {np.mean(sims):.4f}")
  print(f"Standard deviation of cosine similarities: {np.std(sims):.4f}")
  print(f"Minimum cosine similarity: {np.min(sims):.4f}")
  print(f"1st quartile cosine similarity: {np.percentile(sims, 25):.4f}")
  print(f"Median cosine similarity: {np.median(sims):.4f}")
  print(f"3rd quartile cosine similarity: {np.percentile(sims, 75):.4f}")
  print(f"Maximum cosine similarity: {np.max(sims):.4f}")

# %%
def save_outputs_to_file(outputs, cosine_similarities, filename, preds=None):
    df_output = df_test.copy()
    df_output["output"] = outputs
    if preds is not None:
        df_output["output_processed"] = preds
    for k, v in cosine_similarities.items():
        df_output[f"cosine_similarity_{k}"] = v
    df_output.to_csv(filename, index=False)

# %% [markdown]
# ## Evaluate model before finetuning

# %%
outputs_before = generate_outputs(test_dataset, model, tokenizer)
# Out:
# 100%|██████████| 5/5 [4:00:01<00:00, 2880.35s/it]

# %%
print_joke_with_output(test_dataset, outputs_before, 10)
# Out:
# Pun: When bottled water is cheap it's called a liquidation sale .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# When bottled water is cheap it's called a liquidation sale . [/INST]sure! Here's why the pun is funny:
#
# The pun is funny because it plays on the double meaning of the word "liquidation." In one sense, "liquidation" can refer to the process of selling off assets at a discounted price, as in a "liquidation sale." However, in the context of water, "liquidation" can also refer to the process of converting a solid into a liquid, as in the act of "liquidating" a solid substance.
#
# The pun works because it takes the common phrase "liquidation sale" and gives it a new, unexpected meaning when applied to water. It's a clever play on words that creates a humorous connection between two seemingly unrelated concepts. The unexpected twist adds to the humor, making it more likely to elicit a chuckle or a smile from the listener.
#
# In addition, the pun is funny because it's a clever use of wordplay, which is a common source of humor. Puns are a type of wordplay that rely on using words in a way that plays on their multiple meanings or sounds similar to another word, often creating a humorous effect. The use of puns can add a lighthearted and playful tone to language, making it more enjoyable to use and hear.
#
# Overall, the pun "When bottled water is cheap, it's called a liquidation sale" is funny because it's a clever play on words that creates a humorous connection between two seemingly unrelated concepts. The unexpected twist and clever use of wordplay make it a enjoyable and amusing phrase to hear or read.
#
# Pun: If intervening was an olympic sport , he'd win the gold meddle .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# If intervening was an olympic sport , he'd win the gold meddle . [/INST]sure! Here's why the pun is funny:
#
# The pun is funny because it plays on the multiple meanings of the word "meddle." In one sense, "meddle" can refer to the act of intervening or interfering in something. In another sense, "meddle" can refer to a small metal object used for measuring, such as a medal. The pun relies on the double meaning of the word to create humor.
#
# The phrase "he'd win the gold meddle" is funny because it takes the expected meaning of the word "meddle" (i.e. interfering) and replaces it with the other meaning (i.e. medal). This unexpected twist creates a sense of surprise and amusement, which is the hallmark of a good pun.
#
# Additionally, the use of the word "meddle" in this context creates a clever play on words, as it is a homophone of "medal," which is the prize awarded to Olympic athletes. This adds an extra layer of humor to the pun, as it creates a clever connection between the two meanings of the word.
#
# Overall, the pun is funny because it uses wordplay and double meanings to create a clever and unexpected punchline.
#
# Pun: I'm always exhausted by Friday , said Tom weakly .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# I'm always exhausted by Friday , said Tom weakly . [/INST] Unterscheidung! *groan* Oh, that's a good one! The pun is funny because "Friday" and "exhausted" sound similar, but they have different meanings. "Friday" is a day of the week, while "exhausted" means feeling extremely tired or drained of energy. So, Tom's statement is a play on words, as he's essentially saying he's feeling "exhausted" by the day of the week, rather than being physically tired. It's a clever and unexpected twist on a common phrase, which is what makes it funny.
#
# Pun: The math teacher was a good dancer - he had algorithm .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# The math teacher was a good dancer - he had algorithm . [/INST]...
#
# Pun: The Loch Ness monster eats fish and ships .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# The Loch Ness monster eats fish and ships . [/INST]sure! Here's why the pun is funny:
#
# The pun is funny because it plays on the multiple meanings of the word "ships." In one sense, a Loch Ness monster is a mythical creature that lives in Loch Ness, a large lake in Scotland. In another sense, "ships" can refer to boats or vessels that transport goods or people. The pun relies on the confusion between these two meanings to create humor.
#
# The phrase "the Loch Ness monster eats fish and ships" is funny because it suggests that the monster is not only a creature that lives in the loch, but also a being that consumes both fish (the aquatic creatures that live in the loch) and ships (the boats or vessels that travel on the loch). This double meaning creates a humorous and unexpected twist on the typical association of a monster with a particular habitat.
#
# Furthermore, the use of the word "eats" in both contexts adds to the humor. The word "eats" is typically associated with food, but in this case, it is used to describe the monster's consumption of both fish and ships. This creates a sense of absurdity and surprise, as it is not what one would typically expect a monster to eat.
#
# Overall, the pun is funny because it relies on a clever play on words and a unexpected twist on the typical association of a monster with a particular habitat. It is a lighthearted and humorous way to poke fun at the idea of a mythical creature living in a loch.
#
# Pun: Some mathematicians are reluctant to cosine a loan .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# Some mathematicians are reluctant to cosine a loan . [/INST]0 Ah, I see! The pun is funny because "cosine" sounds like "costs," which is a common term for money that needs to be repaid. So, the pun is playing on the idea that some mathematicians are hesitant to "cosine" a loan, or in other words, they are hesitant to pay back a loan. It's a clever play on words that uses the mathematical term "cosine" in a humorous way!
#
# Pun: On cooking shows , there is little margarine of error .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# On cooking shows , there is little margarine of error . [/INST]0 The pun "On cooking shows, there is little margarine of error" is funny because it plays on the double meaning of the word "margarine." In cooking, margarine is a type of butter substitute, but the phrase "margarine of error" sounds like "margin of error," which is a term used in statistics and mathematics to refer to the amount of uncertainty or uncertainty in a measurement or calculation.
#
# The pun works because it takes the common phrase "margin of error" and replaces the word "margin" with "margarine," creating a humorous connection between the two meanings. The result is a clever and unexpected twist on a familiar phrase, which can elicit a chuckle or a smile from the listener.
#
# The humor in the pun comes from the unexpected juxtaposition of the two meanings of the word "margarine," which creates a sense of surprise and cleverness. It's a lighthearted and playful way to poke fun at the sometimes-serious world of cooking shows, while also showcasing a clever turn of phrase.
#
# Pun: A surgery nurse was demoted for being absent without gauze .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# A surgery nurse was demoted for being absent without gauze . [/INST]0 The pun is funny because it plays on the double meaning of the word "gauze." In medical contexts, gauze is a type of thin, absorbent fabric used to dress wounds or apply pressure to stop bleeding. However, "absent without gauze" can also be interpreted as "absent without excuse," implying that the nurse was absent from work without a valid reason.
#
# The humor comes from the unexpected twist on the word "gauze," which creates a pun that is both clever and amusing. The use of wordplay can create a sense of surprise and delight, making the pun more likely to be well-received and remembered.
#
# In addition, the pun is funny because it is a clever play on words that subverts the expected meaning of the word "gauze." The pun is not obvious or forced, but rather subtle and unexpected, which makes it more likely to elicit a chuckle.
#
# Overall, the pun is funny because it uses wordplay to create a clever and unexpected twist on a common medical term, which creates a sense of surprise and delight in the listener.
#
# Pun: The magician who loved his chocolate could perform a lot of Twix .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# The magician who loved his chocolate could perform a lot of Twix . [/INST]0 The pun is funny because it plays on the multiple meanings of the word "Twix." In one sense, "Twix" can refer to a brand of chocolate candy bar. However, the word "twix" can also mean "between" or "among," as in "a twix two things." The pun relies on the double meaning of the word to create humor.
#
# The joke works because it sets up an expectation that the magician will perform a magic trick involving the chocolate candy bar Twix, but then subverts that expectation by using the word "twix" in a different context, implying that the magician is capable of performing magic between or among things, rather than just with a specific candy bar. The unexpected twist creates humor and catches the listener off guard, making the pun funny.
#
# Additionally, the use of wordplay and puns is a common technique in humor, as it creates a sense of cleverness and wit. The pun on "Twix" is a clever play on words that adds to the humor of the joke.
#
# Overall, the pun on "Twix" is funny because it relies on a clever play on words, subverts expectations, and creates a sense of cleverness and wit.
#
# Pun: In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon . [/INST]  The pun is funny because it plays on the multiple meanings of the word "galleon." In ancient times, a galleon was a type of ship used for sailing across the ocean. However, in modern times, "galleon" can also refer to a large quantity or a lot of something, as in "I have a galleon of money."
#
# The pun relies on the unexpected twist of using the word "galleon" in a different context, creating a humorous connection between the two meanings. The punchline, "They got thousands of miles to the galleon," is a play on words that creates a humorous image of ancient sailors traveling long distances on their ships, while also referencing the modern meaning of "galleon" as a large quantity.
#
# The humor in the pun comes from the clever manipulation of language, creating a unexpected and amusing connection between two seemingly unrelated concepts. The pun is funny because it is unexpected and cleverly constructed, and it creates a humorous image that is both silly and memorable.

# %%
cosine_similarities_before, _ = calculate_cosine_similarity(test_dataset, outputs_before)

# %%
evaluate_cosine_similarity(cosine_similarities_before["mean"])
# Out:
# Mean cosine similarity: 0.6916
# Standard deviation of cosine similarities: 0.1919
# Minimum cosine similarity: 0.2815
# 1st quartile cosine similarity: 0.7193
# Median cosine similarity: 0.7782
# 3rd quartile cosine similarity: 0.8063
# Maximum cosine similarity: 0.8734

# %%
save_outputs_to_file(outputs_before, cosine_similarities_before, "before_finetuning.csv")

# %% [markdown]
# ## Train model

# %%
# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    peft_config=peft_config,
    dataset_text_field="model_train_input_text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(

# %%
# Train model
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='575' max='575' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [575/575 21:57, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>2.505500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.312800</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.371600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.183700</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.323000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.144900</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>1.297400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.120300</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>1.162300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.046000</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>1.182500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.039700</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>1.164400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.988300</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>1.127600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.011500</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>1.095900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.949700</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>1.040400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.878900</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>1.093400</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.887400</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>0.968500</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=575, training_loss=1.1693735902205757, metrics={'train_runtime': 1321.4601, 'train_samples_per_second': 1.74, 'train_steps_per_second': 0.435, 'total_flos': 4292629992407040.0, 'train_loss': 1.1693735902205757, 'epoch': 1.0})

# %%
trainer.save_model(new_model)

# %%
import os
from zipfile import ZipFile

# Set the directory to be zipped
folder_to_zip = f"/content/{new_model}"

# Set the output zip file name
zip_filename = f"{new_model}.zip"

# Create a ZipFile object
with ZipFile(zip_filename, 'w') as zip_file:
    # Walk through the folder and add each file to the zip
    for root, dirs, files in os.walk(folder_to_zip):
        for file in files:
            file_path = os.path.join(root, file)
            zip_file.write(file_path)

print(f"Zip file '{zip_filename}' created successfully!")
# Out:
# Zip file 'llama-2-7b-finetuned.zip' created successfully!

# %% [markdown]
# ## Evaluate model after finetuning

# %%
outputs_after = generate_outputs(test_dataset, model, tokenizer)
# Out:
# 100%|██████████| 5/5 [5:45:13<00:00, 4142.61s/it]

# %%
print_joke_with_output(test_dataset, outputs_after, 10)
# Out:
# Pun: When bottled water is cheap it's called a liquidation sale .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# When bottled water is cheap it's called a liquidation sale . [/INST]
# This is a play on words. The word "liquidation" means the process of selling off assets to pay off debts.  "Liquid" is a synonym for "water".</s>
#
# The joke is a pun.  A "liquidation sale" is a sale where assets are sold off to pay off debts.  "Liquid" is a synonym for "water".  The joke is playing on the word "liquidation" and replacing it with "liquid".</s>
#
# The joke is a play on words.  The word "liquidation" means the process of selling off assets to pay off debts.  "Liquid" is a synonym for "water".  The joke is a pun.  A "liquidation sale" is a sale where assets are sold off to pay off debts.  "Liquid" is a synonym for "water".  The joke is playing on the word "liquidation" and replacing it with "liquid".</s>
#
# The joke is a pun.  A "liquidation sale" is a sale where assets are sold off to pay off debts.  "Liquid" is a synonym for "water".  The joke is playing on the word "liquidation" and replacing it with "liquid".</s>
#
# The joke is a pun.  A "liquidation sale" is a sale where assets are sold off to pay off debts.  "Liquid" is a synonym for "water".  The joke is playing on the word "liquidation" and replacing it with "liquid".</s>
#
# The joke is a pun.  A "liquidation sale" is a sale where assets are sold off to pay off debts.  "Liquid" is a synonym for "water".  The joke is playing on the word "liquidation" and replacing it with "liquid".</s>
#
# The joke is a pun.  A "liquidation sale" is a sale where assets are sold off to pay off debts.  "Liquid" is a synonym for "water".  The joke is playing on the word "liquidation
#
# Pun: If intervening was an olympic sport , he'd win the gold meddle .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# If intervening was an olympic sport , he'd win the gold meddle . [/INST]
# This is a pun on the word 'meddle'.  'Meddle' sounds like 'medal', which is a prize given to winners of the Olympics.</s>
#
# Here, 'gold meddle' is used instead of 'gold medal' because the joke is about meddling, which is a type of intervention.</s>
#
# The joke is playing on the word 'meddle' because it sounds like 'medal', and because the joke is about intervention.</s>
#
# The joke is saying that if he was an Olympic athlete, he would win the gold medal, but instead he's an interventionist, so he'd win the gold meddle.</s>
#
# The joke is a play on words.  'Meddle' sounds like 'medal', and it's being used because the joke is about intervention.</s>
#
# The joke is saying that if he was an Olympic athlete, he would win the gold medal, but instead he's an interventionist, so he'd win the gold meddle.</s>
#
# The joke is a pun.  'Meddle' sounds like 'medal', and it's being used because the joke is about intervention.</s>
#
# The joke is saying that if he was an Olympic athlete, he would win the gold medal, but instead he's an interventionist, so he'd win the gold meddle.</s>
#
# The joke is a pun.  'Meddle' sounds like 'medal', and it's being used because the joke is about intervention.</s>
#
# The joke is saying that if he was an Olympic athlete, he would win the gold medal, but instead he's an interventionist, so he'd win the gold meddle.</s>
#
# The joke is a pun.  'Meddle' sounds like 'medal', and it's being used because the joke is about intervention.</s>
#
# The joke is saying that if he was an Olympic athlete, he would win the gold medal, but instead he's an interventionist, so he'd win the gold meddle.</s>
#
#
#
# Pun: I'm always exhausted by Friday , said Tom weakly .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# I'm always exhausted by Friday , said Tom weakly . [/INST]
# This is a pun on the word 'weakly'.  'Weakly' means in a weak manner, but it's also being used because 'Tom' sounds like 'tired'.  Tom is tired, so he's saying it weakly.</s>
#
# Tom is tired because it's Friday.  Fridays are usually the most exhausting day of the week because it's the end of the week and people are tired from working all week.  Tom is saying that he's tired because it's Friday.</s>
#
# Tom is also saying that he's tired in a weak manner.  He's not saying it with much conviction or energy.  He's just saying it because he's tired.</s>
#
# The joke is a pun.  'Weakly' is being used to mean 'tired', but it's also being used because 'Tom' sounds like 'tired'.</s>
#
# The joke is a pun.  It's a play on words.  'Weakly' is being used to mean 'tired', but it's also being used because 'Tom' sounds like 'tired'.</s>
#
# The joke is a pun.  It's a play on words.  'Weakly' is being used to mean 'tired', but it's also being used because 'Tom' sounds like 'tired'.</s>
#
# The joke is a pun.  It's a play on words.  'Weakly' is being used to mean 'tired', but it's also being used because 'Tom' sounds like 'tired'.</s>
#
# The joke is a pun.  It's a play on words.  'Weakly' is being used to mean 'tired', but it's also being used because 'Tom' sounds like 'tired'.</s>
#
# The joke is a pun.  It's a play on words.  'Weakly' is being used to mean 'tired', but it's also being used because 'Tom' sounds like 'tired'.</s>
#
# The joke is a pun.  It's a play on words.  'Weakly' is being used to mean '
#
# Pun: The math teacher was a good dancer - he had algorithm .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# The math teacher was a good dancer - he had algorithm . [/INST]] This is a pun on the word "algorithm".  An algorithm is a set of instructions for solving a mathematical problem.  A "jig" is a dance move.  The joke is that the math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a play on words.  The word "algorithm" sounds like "jig" which is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.  The math teacher is a good dancer because he has "algorithm" which sounds like "jig".</s>
#
# The joke is a pun.  A "jig" is a dance move.
#
# Pun: The Loch Ness monster eats fish and ships .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# The Loch Ness monster eats fish and ships . [/INST]] This is a pun on the word 'ships'.  'Ships' sounds like 'ships' which is a type of food.  The Loch Ness monster is a sea monster that lives in Loch Ness, a lake in Scotland.  Loch Ness is a body of water, and 'ships' is a type of food that is eaten in the water.</s>
#
# The joke is a play on words.  The word 'ships' sounds like 'ships' which is a type of food.  The Loch Ness monster is a sea monster that lives in Loch Ness, a body of water.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water.</s>
#
# The joke is a pun.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water.  The Loch Ness monster is a sea monster that lives in Loch Ness, a body of water.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water.</s>
#
# The joke is a pun.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water.  The Loch Ness monster is a sea monster that lives in Loch Ness, a body of water.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water.</s>
#
# The joke is a pun.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water.  The Loch Ness monster is a sea monster that lives in Loch Ness, a body of water.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water.</s>
#
# The joke is a pun.  The word 'ships' is being used because it sounds like 'ships' which is a type of food that is eaten in the water
#
# Pun: Some mathematicians are reluctant to cosine a loan .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# Some mathematicians are reluctant to cosine a loan . [/INST]] This is a pun on the word 'cosine'.  'Cosine' is a mathematical term that is used to describe the ratio of the length of the side of a triangle to the length of the adjacent side.  'Cosine' sounds like 'consine', which means to agree or to be in agreement.  The joke is that the mathematicians are reluctant to cosine a loan, which means they are reluctant to agree to a loan.  The joke is playing on the word 'cosine' and how it sounds like 'consine'.</s>
#
# The joke is a play on words.  'Cosine' is a mathematical term that is used to describe the ratio of the length of the side of a triangle to the length of the adjacent side.  'Cosine' sounds like 'consine', which means to agree or to be in agreement.  The joke is that the mathematicians are reluctant to cosine a loan, which means they are reluctant to agree to a loan.  The joke is playing on the word 'cosine' and how it sounds like 'consine'.</s>
#
# The joke is a pun.  'Cosine' is a mathematical term that is used to describe the ratio of the length of the side of a triangle to the length of the adjacent side.  'Cosine' sounds like 'consine', which means to agree or to be in agreement.  The joke is that the mathematicians are reluctant to cosine a loan, which means they are reluctant to agree to a loan.  The joke is playing on the word 'cosine' and how it sounds like 'consine'.</s>
#
# The joke is a pun.  'Cosine' is a mathematical term that is used to describe the ratio of the length of the side of a triangle to the length of the adjacent side.  'Cosine' sounds like 'consine', which means to agree or to be in agreement.  The joke is that the mathematicians are reluctant to cosine a loan, which means they are reluctant to agree to a loan.  The joke is playing on the word 'cosine' and how it sounds like 'consine'.</s>
#
# The joke is a
#
# Pun: On cooking shows , there is little margarine of error .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# On cooking shows , there is little margarine of error . [/INST]
# Margarine is a type of butter substitute.  To have a "margarine of error" means to have a small amount of error.  This is a pun on "margarine" because it sounds like "margin of error".  A margin of error is a small amount of error that is allowed in a calculation or measurement.  In cooking, a small amount of error can make a big difference in the taste of the food.</s>
#
# Cooking shows are television shows that show people cooking food.  They are often hosted by chefs or other people who are experienced in cooking.  Chefs are people who are experienced in cooking food.  They are often on television shows to show people how to cook food.  They are also often on television shows to promote their cookbooks or restaurants.</s>
#
# Cooking shows are often on television during the day.  They are often on during the day because people are more likely to be home during the day.  They are also often on during the day because it is easier to film during the day.  It is easier to film during the day because the lighting is better.  It is also easier to film during the day because there are more people awake and watching television during the day.</s>
#
# Cooking shows are often on television during the day.  They are often on during the day because people are more likely to be home during the day.  They are also often on during the day because it is easier to film during the day.  It is easier to film during the day because the lighting is better.  It is also easier to film during the day because there are more people awake and watching television during the day.</s>
#
# Cooking shows are often on television during the day.  They are often on during the day because people are more likely to be home during the day.  They are also often on during the day because it is easier to film during the day.  It is easier to film during the day because the lighting is better.  It is also easier to film during the day because there are more people awake and watching television during the day.</s>
#
# Cooking shows are often on television during the day.  They are often on during the day because people are more likely to be home during the day.  They are also often on
#
# Pun: A surgery nurse was demoted for being absent without gauze .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# A surgery nurse was demoted for being absent without gauze . [/INST]] This is a pun on the word 'absent'.  Gauze is a type of cloth used in surgery.  To be 'absent' means to be away from work without permission.</s>
#
# A surgery nurse is someone who helps doctors during surgery.  They are responsible for keeping the patient calm and comfortable during the surgery.  They also help the doctor by holding gauze to the patient's wounds.  To be 'absent without gauze' means to be away from work without permission, but also to be away from the gauze that is used in surgery.</s>
#
# The joke is a pun.  The phrase 'absent without excuse' means to be away from work without permission.  The phrase 'absent without gauze' is used instead because 'gauze' is a type of cloth used in surgery.  The joke is playing on the word 'absent' and how it can be used in different ways.</s>
#
# The joke is a pun.  The phrase 'absent without excuse' means to be away from work without permission.  The phrase 'absent without gauze' is used instead because 'gauze' is a type of cloth used in surgery.  The joke is playing on the word 'absent' and how it can be used in different ways.</s>
#
# The joke is a pun.  The phrase 'absent without excuse' means to be away from work without permission.  The phrase 'absent without gauze' is used instead because 'gauze' is a type of cloth used in surgery.  The joke is playing on the word 'absent' and how it can be used in different ways.</s>
#
# The joke is a pun.  The phrase 'absent without excuse' means to be away from work without permission.  The phrase 'absent without gauze' is used instead because 'gauze' is a type of cloth used in surgery.  The joke is playing on the word 'absent' and how it can be used in different ways.</s>
#
# The joke is a pun.  The phrase 'absent without excuse' means to be away from work without permission.  The phrase 'absent without gauze' is used
#
# Pun: The magician who loved his chocolate could perform a lot of Twix .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# The magician who loved his chocolate could perform a lot of Twix . [/INST]] twix is a brand of candy that is a cookie with a caramel filling. twix sounds like tricks, which is what magicians do.</s>
#
# The joke is a pun.  'Tricks' is a word that sounds like 'twix'.  'Twix' is a brand of candy that is a cookie with a caramel filling.</s>
#
# The joke is a play on words.  The word 'tricks' sounds like 'twix'.  'Twix' is a brand of candy that is a cookie with a caramel filling.</s>
#
# The joke is a pun.  'Twix' is a brand of candy that is a cookie with a caramel filling.  'Tricks' is a word that sounds like 'twix'.</s>
#
# The joke is a pun.  'Twix' is a brand of candy that is a cookie with a caramel filling.  'Tricks' is a word that sounds like 'twix'.  The joke is a play on words.  'Twix' sounds like 'tricks'.</s>
#
# The joke is a pun.  'Twix' is a brand of candy that is a cookie with a caramel filling.  'Tricks' is a word that sounds like 'twix'.  The joke is a play on words.  'Twix' sounds like 'tricks'.</s>
#
# The joke is a pun.  'Twix' is a brand of candy that is a cookie with a caramel filling.  'Tricks' is a word that sounds like 'twix'.  The joke is a play on words.  'Twix' sounds like 'tricks'.</s>
#
# The joke is a pun.  'Twix' is a brand of candy that is a cookie with a caramel filling.  'Tricks' is a word that sounds like 'twix'.  The joke is a play on words.  'Twix' sounds like 'tricks'.</s>
#
# The joke is a pun.  'Twix' is a brand of candy that is a cookie with a caramel filling.  'Tricks' is a word
#
# Pun: In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon .
# Output: [INST] <<SYS>>
# Provide an explanation on why this pun is funny.
# <</SYS>>
#
# In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon . [/INST] galleon sounds like gallon, and a gallon is a unit of measurement for volume of liquid</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. The joke is playing on the word "gallon" which sounds like "galleon".</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. The joke is playing on the word "gallon" which sounds like "galleon".</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. The joke is playing on the word "gallon" which sounds like "galleon".</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. The joke is playing on the word "gallon" which sounds like "galleon".</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. The joke is playing on the word "gallon" which sounds like "galleon".</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. The joke is playing on the word "gallon" which sounds like "galleon".</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. The joke is playing on the word "gallon" which sounds like "galleon".</s>
#
# A galleon is a type of ship that was used in the 16th and

# %%
cosine_similarities_after, preds = calculate_cosine_similarity(test_dataset, outputs_after)
# Out:
# 100%|██████████| 115/115 [02:08<00:00,  1.12s/it]

# %%
evaluate_cosine_similarity(cosine_similarities_after["mean"])
# Out:
# Mean cosine similarity: 0.8207
# Standard deviation of cosine similarities: 0.0405
# Minimum cosine similarity: 0.6825
# 1st quartile cosine similarity: 0.7936
# Median cosine similarity: 0.8255
# 3rd quartile cosine similarity: 0.8533
# Maximum cosine similarity: 0.8888

# %%
save_outputs_to_file(outputs_after, cosine_similarities_after, "after_finetuning.csv", preds=preds)
