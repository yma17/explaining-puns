# %% [markdown]
# ## Setup notebook
# **First, set the notebook runtime to T4 GPU.**
# Steps derived from this article: https://mlabonne.github.io/blog/posts/Fine_Tune_Your_Own_Llama_2_Model_in_a_Colab_Notebook.html

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 44.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 25.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 40.7 MB/s eta 0:00:00

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    StoppingCriteria,
    StoppingCriteriaList,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %%
# The model that you want to train from the Hugging Face hub
model_name = "NousResearch/llama-2-7b-chat-hf"

# Fine-tuned model name
new_model = "llama-2-7b-finetuned"  # TODO - change this depending on finetuning task

# %%
################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

# %%
################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

# %%
################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule (constant a bit better than cosine)
lr_scheduler_type = "constant"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 25

# Log every X updates steps
logging_steps = 25

# %%
################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %% [markdown]
# ## Define prompt

# %%
prompt = "You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny."

# %% [markdown]
# ## Load data
#
# The following prompt template is used to format the training and inference inputs:
# - Training: https://huggingface.co/datasets/mlabonne/guanaco-llama2-1k
# - Inference: https://gpus.llm-utils.org/llama-2-prompt-template/

# %%
# Load dataset
import pandas as pd

filename_train_dataset = "data/train_explanations.csv"  # each row is an explanation; for training!
filename_test_dataset = "data/test_jokes.csv"  # each row is a joke; for inference!

train_dataset = load_dataset('csv', data_files=filename_train_dataset, split="train")
test_dataset = load_dataset('csv', data_files=filename_test_dataset, split="train")

df_train = pd.read_csv(filename_train_dataset)
df_test = pd.read_csv(filename_test_dataset)

df_train["model_train_input_text"] = df_train.apply(lambda x: "<s>[INST] <<SYS>>\n" + prompt + "\n<</SYS>>\n\n" + x["text"] + " [/INST] " + x["Natural language explanation"] + "</s>", axis=1)
df_test["model_inference_input_text"] = df_test.apply(lambda x: "<s>[INST] <<SYS>>\n" + prompt + "\n<</SYS>>\n\n" + x["text"] + " [/INST]", axis=1)

train_dataset = train_dataset.add_column(name="model_train_input_text", column=df_train["model_train_input_text"].to_list())
test_dataset = test_dataset.add_column(name="model_inference_input_text", column=df_test["model_inference_input_text"].to_list())

print(train_dataset)  # number of explanations; divide by 5 to get number of jokes
print(test_dataset)  # number of jokes; multiply by 5 to get number of explanations
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['ID', 'Annotator_ID', 'Funniness (1-5)', 'Is a Joke?', 'Joke keywords', 'Natural language explanation', 'Offensive/Inappropriate?', 'Understand the text?', 'text', 'model_train_input_text'],
#     num_rows: 2300
# })
# Dataset({
#     features: ['ID', 'text', 'Natural language explanation 1', 'Natural language explanation 2', 'Natural language explanation 3', 'Natural language explanation 4', 'Natural language explanation 5', 'model_inference_input_text'],
#     num_rows: 115
# })

# %% [markdown]
# ## Finetuning methods

# %%
from tqdm import tqdm

def generate_outputs(dataset, model, tokenizer, batch_size=24, max_new_tokens=500):
    """Generate outputs for each input in the dataset."""
    input_texts = [example["model_inference_input_text"] for example in dataset]
    output_texts = []

    for i in tqdm(list(range(0, len(input_texts), batch_size))):  # for each batch
        input_texts_batch = input_texts[i:min(i+batch_size,len(input_texts))]

        # Tokenize
        tokenize_result = tokenizer(input_texts_batch, return_tensors="pt", padding=True).to(model.device)

        # Generate outputs
        with torch.no_grad():
            outputs_batch = model.generate(**tokenize_result,
                                           max_new_tokens=max_new_tokens)

        # Decode outputs
        output_texts_batch = tokenizer.batch_decode(outputs_batch, skip_special_tokens=True)
        output_texts.extend(output_texts_batch)

    return output_texts

def print_joke_with_output(dataset, outputs, limit):
    for i, example in enumerate(dataset):
        if i == limit:
            break
        print("Pun:", example["text"])
        print("Output:", outputs[i])
        print()

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
from statistics import mean
import numpy as np

def get_sentence_embedding(sentence, model, tokenizer):
    """
    Get the sentence embedding for a given sentence.
    """
    input_ids = tokenizer.encode(sentence, return_tensors='pt')
    with torch.no_grad():
        output = model(input_ids)[0]
    sentence_embedding = torch.mean(output, dim=1).squeeze()
    return sentence_embedding.detach().cpu().numpy()

def calculate_cosine_similarity(dataset, outputs):
    """
    Calculate the cosine similarity between the prediction and ground truth for the entire dataset.
    """
    model_name = 'bert-base-uncased'
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    cosine_similarities = {"1": [], "2": [], "3": [], "4": [], "5": [], "mean": []}
    preds = []

    dataset = dataset.add_column(name="model_output_text", column=outputs)
    for example in tqdm(dataset):

        pred = example['model_output_text']
        if "[/INST]" in pred:
            idx = pred.index("[/INST]") + len("[/INST]")
            pred = pred[idx:]
        if "</s>" in pred:
            idx = pred.index("</s>")
            pred = pred[:idx]
        if len(pred) > 512:  # manual truncation
            pred = pred[:512]
        pred = pred[1:]  # remove newline or leading ']' character
        pred = pred.strip()  # remove leading or trailing whitespace
        preds.append(pred)

        pred_embedding = get_sentence_embedding(pred, model, tokenizer)

        cosine_similarities_example = []
        for i in range(5):
            groundtruth = example[f'Natural language explanation {i + 1}']
            groundtruth_embedding = get_sentence_embedding(groundtruth, model, tokenizer)

            cosine_sim = cosine_similarity([pred_embedding], [groundtruth_embedding])[0][0]
            cosine_similarities_example.append(cosine_sim)
            cosine_similarities[f"{i + 1}"].append(cosine_sim)

        cosine_similarities["mean"].append(mean(cosine_similarities_example))

    return cosine_similarities, preds

# %%
def evaluate_cosine_similarity(sims):
  print(f"Mean cosine similarity: {np.mean(sims):.4f}")
  print(f"Standard deviation of cosine similarities: {np.std(sims):.4f}")
  print(f"Minimum cosine similarity: {np.min(sims):.4f}")
  print(f"1st quartile cosine similarity: {np.percentile(sims, 25):.4f}")
  print(f"Median cosine similarity: {np.median(sims):.4f}")
  print(f"3rd quartile cosine similarity: {np.percentile(sims, 75):.4f}")
  print(f"Maximum cosine similarity: {np.max(sims):.4f}")

# %%
def save_outputs_to_file(outputs, cosine_similarities, filename, preds=None):
    df_output = df_test.copy()
    df_output["output"] = outputs
    if preds is not None:
        df_output["output_processed"] = preds
    for k, v in cosine_similarities.items():
        df_output[f"cosine_similarity_{k}"] = v
    df_output.to_csv(filename, index=False)

# %% [markdown]
# ## Evaluate model before finetuning

# %%
outputs_before = generate_outputs(test_dataset, model, tokenizer)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# 100%|██████████| 5/5 [4:21:48<00:00, 3141.65s/it]

# %%
print_joke_with_output(test_dataset, outputs_before, 10)
# Out:
# Pun: When bottled water is cheap it's called a liquidation sale .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# When bottled water is cheap it's called a liquidation sale . [/INST]sure, I'd be happy to help you analyze the humor in this joke!
#
# The joke relies on a clever play on words to create humor. The term "liquidation sale" typically refers to a sale where items are being sold at a discounted price, often to liquidate inventory that is no longer needed or to clear out old stock. However, in this joke, the term is applied to bottled water, which is something that is typically not sold at a discounted price.
#
# The humor comes from the unexpected twist on the term "liquidation sale." Our brains are wired to recognize patterns and expectations, and when we hear the term "liquidation sale" in a context where it doesn't fit, it creates a cognitive dissonance that can be funny. The joke is also a play on words, as the word "liquidation" can also refer to the process of selling off assets to settle debts or liquidate a business.
#
# Another aspect of the joke that contributes to its humor is the use of wordplay. The joke relies on the double meaning of the word "liquidation" to create a pun. The use of puns can be a powerful tool for humor, as they create a sense of surprise and delight in the listener.
#
# Overall, the joke is funny because it uses a clever play on words to create a unexpected twist on a familiar term, which creates a cognitive dissonance that can be humorous. The use of puns also adds to the humor, as it creates a sense of surprise and delight in the listener.
#
# Pun: If intervening was an olympic sport , he'd win the gold meddle .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# If intervening was an olympic sport , he'd win the gold meddle . [/INST]sure, I'd be happy to analyze the joke "If intervening was an Olympic sport, he'd win the gold medal." Here's my breakdown of the joke:
#
# **Wordplay:** The joke relies on a clever play on words, using the word "meddle" instead of "medal." "Meddle" has a double meaning here, as it can refer to both interfering or meddling in something, but it also sounds similar to "medal." This wordplay creates a funny and unexpected twist on the expected meaning of the word, which adds to the humor.
#
# **Setup:** The setup of the joke is simple and straightforward. It establishes a scenario where someone is good at something, in this case, intervening. This sets the stage for the punchline.
#
# **Punchline:** The punchline is the payoff of the joke, and it's where the humor comes from. "If intervening was an Olympic sport, he'd win the gold medal" is a clever and unexpected twist on the expected meaning of the word "medal." It's funny because it takes the common understanding of the word "medal" and turns it on its head, creating a humorous and unexpected punchline.
#
# **Comedic techniques:** There are a few comedic techniques at play in this joke. One is the use of understatement, as the joke implies that the person is so good at intervening that they would win a gold medal in it. Another technique is the use of wordplay, as I mentioned earlier. Finally, there's a bit of irony in the joke, as the word "meddle" has a double meaning that adds to the humor.
#
# **Puns:** Yes, there is a pun in the joke. The use of "meddle" instead of "medal" is a pun, as it plays on the multiple meanings of the word.
#
# Overall, the joke is funny because it relies on clever wordplay, a simple and relatable setup, and a unexpected twist on the expected meaning of a word. The use of irony and puns also add to the humor.
#
# Pun: I'm always exhausted by Friday , said Tom weakly .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# I'm always exhausted by Friday , said Tom weakly . [/INST]sure, I'd be happy to help you analyze the humor in the joke!
#
# The joke is funny because it plays on the idea of Tom being exhausted by Friday, which is a common feeling for many people. The word "exhausted" has a double meaning here, as it can refer to both Tom's physical state (he is tired) and the day of the week (Friday). The punchline, "said Tom weakly," adds to the humor by implying that Tom is not just tired, but also weak or lacking in energy, which makes the situation even more amusing.
#
# The setup of the joke is simple and straightforward, which allows the punchline to take center stage. The use of the word "said" to introduce the punchline creates a sense of normalcy and everydayness, which makes the punchline more unexpected and therefore funnier.
#
# The comedic technique used in this joke is wordplay, specifically a pun. The use of the word "weakly" to describe Tom's state is a play on words, as it can also refer to the day of the week (Friday). This type of wordplay creates a sense of surprise and delight, which is a key element of humor.
#
# Overall, the joke is funny because it uses a simple setup and punchline to create a pun that plays on the double meaning of the word "exhausted." The use of wordplay and the unexpected twist at the end of the joke create a sense of surprise and delight, which are key elements of humor.
#
# Pun: The math teacher was a good dancer - he had algorithm .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# The math teacher was a good dancer - he had algorithm . [/INST]sure, I'd be happy to help you analyze the humor in the joke!
#
# The joke is funny because it uses a clever play on words. The word "algorithm" has a double meaning here. In mathematics, an algorithm is a set of instructions for solving a problem. However, the word "algorithm" also sounds similar to the word "dance," which is a type of movement. The joke is setting up the expectation that the math teacher is good at math, but then subverts it by using the word "algorithm" to refer to dancing.
#
# The punchline is unexpected and clever, which is a key element of humor. It's unexpected because the word "algorithm" doesn't typically have anything to do with dancing, so it creates a sense of surprise or confusion. The joke is also clever because it uses a word that has a double meaning, which adds to the humor.
#
# Another comedic technique used in this joke is puns. A pun is a play on words that exploits multiple meanings of a term, or similar-sounding words. In this case, the joke relies on the similarity in sound between "algorithm" and "dance."
#
# Overall, the joke is funny because it uses a clever play on words, unexpected punchline, and puns to create humor. The joke is well-crafted and has a clear setup and payoff, which adds to its overall effectiveness.
#
# Pun: The Loch Ness monster eats fish and ships .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# The Loch Ness monster eats fish and ships . [/INST]sure, I'd be happy to help you analyze the humor in the joke "The Loch Ness monster eats fish and ships."
#
# The humor in this joke comes from the clever play on words. The phrase "eats fish" is a common phrase used to describe someone who enjoys eating fish, but in this joke, it also has a double meaning. The Loch Ness monster is a mythical creature that is said to live in Loch Ness, a large lake in Scotland. The punchline "ships" is a pun on the word "ships," which can refer to both a type of boat and the act of sending something through the mail.
#
# So, the joke is funny because it takes the phrase "eats fish" and gives it a unexpected twist by replacing the word "fish" with "ships." This creates a humorous connection between the idea of a mythical creature eating fish in a lake and the idea of sending something through the mail. The humor comes from the unexpected twist and the clever wordplay.
#
# Another aspect of the joke that contributes to its humor is the use of alliteration. The "s" sound in "eats" and "ships" creates a pleasing sound that adds to the overall humor of the joke.
#
# Overall, the humor in this joke comes from the clever play on words and the unexpected twist on a common phrase. The use of alliteration also adds to the overall effect of the joke, making it more enjoyable and memorable.
#
# Pun: Some mathematicians are reluctant to cosine a loan .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# Some mathematicians are reluctant to cosine a loan . [/INST]{start}
#
# Ah, a clever play on words! The joke is funny because it takes a common mathematical concept, "cosine," and replaces it with "loan," creating a pun that is both unexpected and amusing. The setup of the joke is simple: it establishes that mathematicians are reluctant to do something, which sets the stage for the punchline.
#
# The punchline, "cosine a loan," is where the humor lies. By replacing "cosine" with "loan," the joke creates a humorous connection between two seemingly unrelated concepts. The word "cosine" is a mathematical term used to describe the angle between two lines, while "loan" is a financial term used to describe a sum of money borrowed. The juxtaposition of these two concepts creates a sense of confusion and absurdity, which is the source of the humor.
#
# The joke also employs a technique called "wordplay," where the same word is used in a different context to create humor. In this case, the word "loan" is used in a mathematical context, which is unexpected and adds to the humor.
#
# Another technique used in this joke is the use of puns. A pun is a play on words that exploits multiple meanings or sounds of a word. In this case, the word "loan" has a double meaning, as it can refer to both a financial transaction and the angle formed by two lines. The use of puns can create humor by exploiting these multiple meanings and creating a sense of cleverness or cleverness.
#
# Overall, the joke is funny because it uses a clever play on words, unexpected juxtaposition of concepts, and wordplay to create a humorous connection between two seemingly unrelated ideas. The use of puns adds an extra layer of humor by exploiting the multiple meanings of the word "loan."{end}
#
# Pun: On cooking shows , there is little margarine of error .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# On cooking shows , there is little margarine of error . [/INST]sure, I'd be happy to help you analyze the humor in the joke "On cooking shows, there is little margarine of error."
#
# The joke relies on a play on words, specifically a pun, to create humor. The word "margarine" is used in two different ways in the joke. The first time it is used, it refers to a type of spread used for cooking. The second time it is used, it sounds similar to the word "margin," which refers to the amount of space or room left between two things.
#
# The humor in the joke comes from the unexpected twist on the word "margarine." The listener expects the joke to be about cooking shows and the ingredients used in cooking, but instead, it takes a turn towards a pun on the word "margin." This unexpected twist creates a sense of surprise and delight, which are key elements of humor.
#
# Another aspect of the joke that contributes to its humor is the use of wordplay. The joke relies on the similarity in sound between "margarine" and "margin," which creates a clever connection between the two meanings of the word. This connection creates a sense of cleverness and wit, which are also important elements of humor.
#
# Overall, the joke "On cooking shows, there is little margarine of error" is funny because it uses a clever play on words to create a unexpected twist on a common phrase. The use of wordplay and puns in the joke adds to its humor and makes it more enjoyable to listen to or read.
#
# Pun: A surgery nurse was demoted for being absent without gauze .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# A surgery nurse was demoted for being absent without gauze . [/INST]sure, I'd be happy to help you analyze the humor in the joke!
#
# The joke is funny because it plays on the double meaning of the word "gauze." In medical contexts, gauze is a type of thin, absorbent fabric used to dress wounds or apply pressure to stop bleeding. However, the phrase "absent without gauze" can also be interpreted as "absent without excuse," implying that the nurse was absent from work without a valid reason.
#
# The setup of the joke is simple and straightforward, establishing the context of a surgery nurse being demoted. The punchline is where the humor lies, as it takes a moment for the listener to understand the double meaning of the word "gauze" and the pun on "absent without excuse."
#
# The joke relies on a technique called "wordplay," where the same word or phrase is used in two different ways to create humor. In this case, the word "gauze" is used both as a medical term and as a pun on the phrase "absent without excuse."
#
# The use of puns in humor is a common technique that can create a sense of surprise and delight in the listener. By using a word or phrase in a new or unexpected way, the joke creates a moment of confusion or misunderstanding, followed by a moment of understanding and appreciation for the clever play on words.
#
# Overall, the joke is funny because it uses wordplay to create a clever and unexpected punchline, and it relies on the double meaning of the word "gauze" to create the humor. The joke is well-crafted and easy to understand, making it accessible and enjoyable for a wide range of listeners.
#
# Pun: The magician who loved his chocolate could perform a lot of Twix .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# The magician who loved his chocolate could perform a lot of Twix . [/INST]/p> Great, let's dive into the joke and analyze why it's funny!
#
# The joke relies on a clever play on words, with the pun on "Twix" being the punchline. The setup of the joke is simple: "The magician who loved his chocolate." This sets the scene for a magician who is passionate about something, but the punchline subverts our expectations by replacing the expected word "tricks" with "Twix."
#
# The humor comes from the unexpected twist on a common phrase. "Twix" is a brand of chocolate bar, but it also sounds similar to the word "tricks," which is what magicians are known for performing. The joke plays on the double meaning of the word, creating a clever and unexpected punchline.
#
# The joke also uses wordplay by replacing the expected word "tricks" with "Twix." This creates a sense of surprise and cleverness, which are key elements of humor. The joke is funny because it takes something familiar (the idea of a magician performing tricks) and twists it in a unexpected way, creating a clever pun.
#
# Another technique used in this joke is the use of alliteration. The words "Twix" and "tricks" start with the same sound, creating a musical quality that adds to the humor.
#
# Overall, the joke is funny because it uses a clever play on words, unexpected twist, and alliteration to create a punchline that is both surprising and clever. The joke's ability to subvert our expectations and create a clever pun is what makes it humorous.
#
# Pun: In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon . [/INST]  Ah, a clever play on words! The joke is funny because it takes a common phrase, "thousands of miles to the gallon," which typically refers to a vehicle's fuel efficiency, and replaces it with "galleon," which is a type of old-fashioned sailing ship. The punchline is unexpected and silly, adding to the humor.
#
# The setup of the joke is simple and straightforward, establishing the context of ancient times and the common phrase. This sets the audience up for the punchline, which is the clever twist on the phrase.
#
# The comedic technique used in this joke is wordplay, specifically puns. The joke relies on the double meaning of the word "galleon," which can refer to both a type of ship and a unit of measurement (a gallon). The use of puns creates a sense of surprise and delight, as the audience recognizes the clever connection between the two meanings of the word.
#
# The joke also employs a play on words, as the phrase "thousands of miles to the galleon" is a clever play on the phrase "thousands of miles to the gallon," which is a common way of expressing a vehicle's fuel efficiency. By replacing "gallon" with "galleon," the joke creates a humorous and unexpected twist on a familiar phrase.
#
# Overall, the joke is funny because it uses clever wordplay and a unexpected twist on a familiar phrase to create a sense of surprise and delight. The use of puns and plays on words adds to the humor, making the joke a clever and enjoyable one.

# %%
cosine_similarities_before, _ = calculate_cosine_similarity(test_dataset, outputs_before)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# 100%|██████████| 115/115 [02:02<00:00,  1.06s/it]

# %%
evaluate_cosine_similarity(cosine_similarities_before["mean"])
# Out:
# Mean cosine similarity: 0.7976
# Standard deviation of cosine similarities: 0.0345
# Minimum cosine similarity: 0.6830
# 1st quartile cosine similarity: 0.7771
# Median cosine similarity: 0.7982
# 3rd quartile cosine similarity: 0.8207
# Maximum cosine similarity: 0.8732

# %%
save_outputs_to_file(outputs_before, cosine_similarities_before, "before_finetuning.csv")

# %% [markdown]
# ## Train model

# %%
# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    peft_config=peft_config,
    dataset_text_field="model_train_input_text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/2300 [00:00<?, ? examples/s]

# %%
# Train model
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='575' max='575' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [575/575 24:41, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>2.309800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.786400</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.959000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.699300</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.928800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.688300</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.905600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.680900</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.803600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.622300</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.824800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.628100</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.815700</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.598500</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.788500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.613700</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.766600</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.578700</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.726400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.533200</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.766600</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.547500</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>0.638500</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=575, training_loss=0.7917826063736625, metrics={'train_runtime': 1486.7362, 'train_samples_per_second': 1.547, 'train_steps_per_second': 0.387, 'total_flos': 6499747922903040.0, 'train_loss': 0.7917826063736625, 'epoch': 1.0})

# %%
trainer.save_model(new_model)

# %%
import os
from zipfile import ZipFile

# Set the directory to be zipped
folder_to_zip = f"/content/{new_model}"

# Set the output zip file name
zip_filename = f"{new_model}.zip"

# Create a ZipFile object
with ZipFile(zip_filename, 'w') as zip_file:
    # Walk through the folder and add each file to the zip
    for root, dirs, files in os.walk(folder_to_zip):
        for file in files:
            file_path = os.path.join(root, file)
            zip_file.write(file_path)

print(f"Zip file '{zip_filename}' created successfully!")
# Out:
# Zip file 'llama-2-7b-finetuned.zip' created successfully!

# %% [markdown]
# ## Evaluate model after finetuning

# %%
outputs_after = generate_outputs(test_dataset, model, tokenizer)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# 100%|██████████| 5/5 [6:43:16<00:00, 4839.24s/it]

# %%
print_joke_with_output(test_dataset, outputs_after, 10)
# Out:
# Pun: When bottled water is cheap it's called a liquidation sale .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# When bottled water is cheap it's called a liquidation sale . [/INST]'Liquidation' is a play on 'liquid' which is a type of water</s>
#
# This is a pun on the word 'liquidation'. Liquidation is a type of sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a play on words. The word 'liquidation' is used to mean a sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a play on words. The word 'liquidation' is used to mean a sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a pun. Liquidation is a type of sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a pun. Liquidation is a type of sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a pun. Liquidation is a type of sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a pun. Liquidation is a type of sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a pun. Liquidation is a type of sale where items are sold at a discounted price. 'Liquid' is a type of water. 'Liquid' sounds like 'liquidation'.</s>
#
# This joke is a pun. Liquidation is a type of sale where items
#
# Pun: If intervening was an olympic sport , he'd win the gold meddle .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# If intervening was an olympic sport , he'd win the gold meddle . [/INST]] This is a pun on the word "meddle".  To meddle means to interfere in someone else's affairs.  It's also a play on the word "medal", which is a prize awarded to the winner of an Olympic event.</s>
#
# The joke is a play on words.  The word "meddle" sounds like "medal".  The phrase "gold medal" is used to describe the highest prize awarded in the Olympics.  The joke is saying that if the person was an Olympic athlete, they would win the gold medal.</s>
#
# The joke is a pun.  The word "meddle" sounds like "medal".  The phrase "gold medal" is used to describe the highest prize awarded in the Olympics.  The joke is saying that if the person was an Olympic athlete, they would win the gold medal.</s>
#
# The joke is a pun.  The word "meddle" sounds like "medal".  The phrase "gold medal" is used to describe the highest prize awarded in the Olympics.  The joke is saying that if the person was an Olympic athlete, they would win the gold medal.</s>
#
# The joke is a pun.  The word "meddle" sounds like "medal".  The phrase "gold medal" is used to describe the highest prize awarded in the Olympics.  The joke is saying that if the person was an Olympic athlete, they would win the gold medal.</s>
#
# The joke is a pun.  The word "meddle" sounds like "medal".  The phrase "gold medal" is used to describe the highest prize awarded in the Olympics.  The joke is saying that if the person was an Olympic athlete, they would win the gold medal.</s>
#
# The joke is a pun.  The word "meddle" sounds like "medal".  The phrase "gold medal" is used to describe the highest prize awarded in the Olympics.  The joke is saying that if the person was an Olympic athlete, they would win the gold medal.</s>
#
# The joke is a pun.  The word "meddle" sounds like "medal".  The phrase "gold medal"
#
# Pun: I'm always exhausted by Friday , said Tom weakly .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# I'm always exhausted by Friday , said Tom weakly . [/INST]] This is a pun on the word "weakly".  "Weakly" means in a weak manner, but "weekly" is used instead because it sounds similar and refers to the day of the week.</s>
#
# The joke is a play on words.  To say something "weakly" means to say it in a weak manner, but "weekly" is used instead because it sounds similar and refers to the day of the week.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is a pun.  The speaker is saying that they are always exhausted by Friday, but they are also saying it in a weak manner.</s>
#
# The joke is
#
# Pun: The math teacher was a good dancer - he had algorithm .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# The math teacher was a good dancer - he had algorithm . [/INST]] This is a pun on the word "algorithm".  An algorithm is a set of instructions for solving a problem.  "Algorithm" sounds like "allegory", which is a story that explains a concept or principle.  The joke is that the math teacher is a good dancer because he has a good "allegory" or "algorithm" for dancing.</s>
#
# The joke is a play on words.  "Algorithm" sounds like "allegory".  An allegory is a story that explains a concept or principle.  "Algorithm" is a set of instructions for solving a problem.  The joke is that the math teacher is a good dancer because he has a good "allegory" or "algorithm" for dancing.</s>
#
# The joke is a pun.  A "algorithm" is a set of instructions for solving a problem.  "Algorithm" sounds like "allegory".  An allegory is a story that explains a concept or principle.  The joke is that the math teacher is a good dancer because he has a good "allegory" or "algorithm" for dancing.</s>
#
# The joke is a pun.  A "algorithm" is a set of instructions for solving a problem.  "Algorithm" sounds like "allegory".  An allegory is a story that explains a concept or principle.  The joke is that the math teacher is a good dancer because he has a good "allegory" or "algorithm" for dancing.</s>
#
# The joke is a pun.  A "algorithm" is a set of instructions for solving a problem.  "Algorithm" sounds like "allegory".  An allegory is a story that explains a concept or principle.  The joke is that the math teacher is a good dancer because he has a good "allegory" or "algorithm" for dancing.</s>
#
# The joke is a pun.  A "algorithm" is a set of instructions for solving a problem.  "Algorithm" sounds like "allegory".  An allegory is a story that explains a concept or principle.  The joke is that the math teacher is a good dancer because he has a good "allegory" or "algorithm" for dancing
#
# Pun: The Loch Ness monster eats fish and ships .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# The Loch Ness monster eats fish and ships . [/INST] in the loch ness monster is a fish eating creature, and ships is a word that sounds like ships and means a company that ships goods</s>
#
# The joke is a pun.  'Ships' is a word that sounds like 'ships' and means a company that ships goods.  'Ships' is also a word that sounds like 'ships' and means a fish eating creature.  The joke is playing on the word 'ships' because it sounds like 'ships' and means a company that ships goods, but it's also being used because it sounds like 'ships' and means a fish eating creature.</s>
#
# The joke is a pun.  'Ships' is a word that sounds like 'ships' and means a company that ships goods.  'Ships' is also a word that sounds like 'ships' and means a fish eating creature.  The joke is playing on the word 'ships' because it sounds like 'ships' and means a company that ships goods, but it's also being used because it sounds like 'ships' and means a fish eating creature.</s>
#
# The joke is a pun.  'Ships' is a word that sounds like 'ships' and means a company that ships goods.  'Ships' is also a word that sounds like 'ships' and means a fish eating creature.  The joke is playing on the word 'ships' because it sounds like 'ships' and means a company that ships goods, but it's also being used because it sounds like 'ships' and means a fish eating creature.</s>
#
# The joke is a pun.  'Ships' is a word that sounds like 'ships' and means a company that ships goods.  'Ships' is also a word that sounds like 'ships' and means a fish eating creature.  The joke is playing on the word 'ships' because it sounds like 'ships' and means a company that ships goods, but it's also being used because it sounds like 'ships' and means a fish eating creature.</s>
#
# The joke is a pun.  'Ships' is a word that sounds like 'ships' and means a company that ships goods.  'Ships' is also a word that sounds like 'ships'
#
# Pun: Some mathematicians are reluctant to cosine a loan .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# Some mathematicians are reluctant to cosine a loan . [/INST] in mathematics, the cosine of a number is the ratio of the length of the side adjacent to the angle to the length of the side opposite the angle.  a loan is a sum of money borrowed from a bank or other lender.</s>
#
# This is a pun on the word 'cosine'.  A 'cosine' is a mathematical term that is used to describe the ratio of the length of a side of a triangle to the length of the adjacent side.  A 'cause' is a reason for something to happen.  A 'cause' is also a noun that refers to a person or thing that is the source of an action or situation.</s>
#
# The joke is a pun.  A 'cosine' is a mathematical term that is used to describe the ratio of the length of a side of a triangle to the length of the adjacent side.  A 'cause' is a reason for something to happen.  A 'cause' is also a noun that refers to a person or thing that is the source of an action or situation.  The joke is a pun on the word 'cosine' because it sounds like 'cause'.</s>
#
# The joke is a pun.  A 'cosine' is a mathematical term that is used to describe the ratio of the length of a side of a triangle to the length of the adjacent side.  A 'cause' is a reason for something to happen.  A 'cause' is also a noun that refers to a person or thing that is the source of an action or situation.</s>
#
# The joke is a pun.  A 'cosine' is a mathematical term that is used to describe the ratio of the length of a side of a triangle to the length of the adjacent side.  A 'cause' is a reason for something to happen.  A 'cause' is also a noun that refers to a person or thing that is the source of an action or situation.</s>
#
# The joke is a pun.  A 'cosine' is a mathematical term that is used to describe the ratio of the length of a side of a triangle to the length of the adjacent side.  A 'cause' is a reason for something to happen.  A 'cause' is also a noun that refers to a person
#
# Pun: On cooking shows , there is little margarine of error .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# On cooking shows , there is little margarine of error . [/INST] butter is called margarine in the UK</s>
#
# This is a pun on the word "margarine".  Margarine is a type of butter that is made from vegetable oils.  It is used in place of butter in the UK.  The joke is saying that there is little "margarine" of error, which means that there is little room for error.  This is a play on the word "margarine" because it sounds like "margin".</s>
#
# The joke is a pun.  A margin is a small amount of space between two things.  It is also a term used in finance.  A margin is the amount of money that a trader must have in their account in order to make a trade.  The joke is saying that there is little room for error, or little margin for error.</s>
#
# The joke is a pun.  A margin is a small amount of space between two things.  It is also a term used in finance.  A margin is the amount of money that a trader must have in their account in order to make a trade.  The joke is saying that there is little room for error, or little margin for error.</s>
#
# The joke is a pun.  A margin is a small amount of space between two things.  It is also a term used in finance.  A margin is the amount of money that a trader must have in their account in order to make a trade.  The joke is saying that there is little room for error, or little margin for error.</s>
#
# The joke is a pun.  A margin is a small amount of space between two things.  It is also a term used in finance.  A margin is the amount of money that a trader must have in their account in order to make a trade.  The joke is saying that there is little room for error, or little margin for error.</s>
#
# The joke is a pun.  A margin is a small amount of space between two things.  It is also a term used in finance.  A margin is the amount of money that a trader must have in their account in order to make a trade.  The joke is saying that there is little room for error,
#
# Pun: A surgery nurse was demoted for being absent without gauze .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# A surgery nurse was demoted for being absent without gauze . [/INST]] This is a pun on the word "gauze". Gauze is a type of cloth used in surgery. The phrase "absent without a trace" means to be completely gone without any trace of where they went. The joke is saying that the nurse was demoted because they were not present for work without any cloth, or gauze.</s>
#
# The joke is a pun.  'Gauze' is a type of cloth used in surgery.  'Absent without a trace' means completely gone without any trace of where they went.  The joke is saying that the nurse was demoted because they were not present for work without any gauze.</s>
#
# The joke is a pun.  'Gauze' is a type of cloth used in surgery.  'Absent without a trace' means completely gone without any trace of where they went.  The joke is saying that the nurse was demoted because they were not present for work without any gauze.</s>
#
# The joke is a pun.  'Gauze' is a type of cloth used in surgery.  'Absent without a trace' means completely gone without any trace of where they went.  The joke is saying that the nurse was demoted because they were not present for work without any gauze.</s>
#
# The joke is a pun.  'Gauze' is a type of cloth used in surgery.  'Absent without a trace' means completely gone without any trace of where they went.  The joke is saying that the nurse was demoted because they were not present for work without any gauze.</s>
#
# The joke is a pun.  'Gauze' is a type of cloth used in surgery.  'Absent without a trace' means completely gone without any trace of where they went.  The joke is saying that the nurse was demoted because they were not present for work without any gauze.</s>
#
# The joke is a pun.  'Gauze' is a type of cloth used in surgery.  'Absent without a trace' means completely gone without any trace of where they went.  The joke is saying that the nurse was demoted because they were not present for work without any gauze
#
# Pun: The magician who loved his chocolate could perform a lot of Twix .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# The magician who loved his chocolate could perform a lot of Twix . [/INST]] This is a pun on the word "twix".  A twix is a type of candy bar that is a cookie with a caramel filling.  The joke is saying that the magician could perform a lot of "twix" which is a play on the word "tricks".</s>
#
# A magician is a performer who uses magic tricks to entertain an audience.  A trick is a magic trick.  A twix is a type of candy bar.  The joke is saying that the magician could perform a lot of tricks, or magic tricks, but also a lot of twix candy bars.</s>
#
# The joke is a pun.  A twix is a type of candy bar.  A twix is also a play on the word "tricks".</s>
#
# The joke is saying that the magician could perform a lot of tricks, or magic tricks, but also a lot of twix candy bars.  The joke is a pun.  The word "twix" is being used in place of the word "tricks".</s>
#
# The joke is a pun.  A twix is a type of candy bar.  A twix is also a play on the word "tricks".</s>
#
# The joke is saying that the magician could perform a lot of tricks, or magic tricks, but also a lot of twix candy bars.  The joke is a pun.  The word "twix" is being used in place of the word "tricks".</s>
#
# The joke is a pun.  A twix is a type of candy bar.  A twix is also a play on the word "tricks".</s>
#
# The joke is saying that the magician could perform a lot of tricks, or magic tricks, but also a lot of twix candy bars.  The joke is a pun.  The word "twix" is being used in place of the word "tricks".</s>
#
# The joke is a pun.  A twix is a type of candy bar.  A twix is also a play on the word "tricks".</s>
#
# The joke is saying
#
# Pun: In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon .
# Output: [INST] <<SYS>>
# You are a bot that specializes in analysis of humor. You specialize in exploring the wordplay, setup of the joke, the punchline, the comedic techniques used, puns, and plays on words. Provide an explanation on why this joke is funny.
# <</SYS>>
#
# In ancient times , seagoing vessels were much more fuel efficient . They got thousands of miles to the galleon . [/INST] galleon sounds like gallon</s>
#
# A galleon is a type of ship that was used in the 16th and 17th centuries. It was a large ship that was used for trade and exploration. A gallon is a unit of measurement for volume. The joke is a pun on the word galleon. The word galleon sounds like gallon, which is a unit of measurement for volume. The joke is saying that the ships of the past were more fuel efficient because they got thousands of miles to the gallon.</s>
#
# The joke is a pun.  A galleon is a type of ship.  A gallon is a unit of measurement for volume.  The joke is saying that the ships of the past were more fuel efficient because they got thousands of miles to the gallon.  The joke is a pun on the word gallon.</s>
#
# The joke is a pun.  A galleon is a type of ship.  A gallon is a unit of measurement for volume.  The joke is saying that the ships of the past were more fuel efficient because they got thousands of miles to the gallon.  The joke is a pun on the word gallon.</s>
#
# The joke is a pun.  A galleon is a type of ship.  A gallon is a unit of measurement for volume.  The joke is saying that the ships of the past were more fuel efficient because they got thousands of miles to the gallon.  The joke is a pun on the word gallon.</s>
#
# The joke is a pun.  A galleon is a type of ship.  A gallon is a unit of measurement for volume.  The joke is saying that the ships of the past were more fuel efficient because they got thousands of miles to the gallon.  The joke is a pun on the word gallon.</s>
#
# The joke is a pun.  A galleon is a type of ship.  A gallon is a unit of measurement for volume.  The joke is saying that the ships of the past were more fuel efficient because they got thousands of miles to the gallon.  The joke is a pun on the word gallon.</s>
#
# The joke is a pun

# %%
cosine_similarities_after, preds = calculate_cosine_similarity(test_dataset, outputs_after)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# 100%|██████████| 115/115 [01:41<00:00,  1.13it/s]

# %%
evaluate_cosine_similarity(cosine_similarities_after["mean"])
# Out:
# Mean cosine similarity: 0.8033
# Standard deviation of cosine similarities: 0.0537
# Minimum cosine similarity: 0.5722
# 1st quartile cosine similarity: 0.7788
# Median cosine similarity: 0.8120
# 3rd quartile cosine similarity: 0.8413
# Maximum cosine similarity: 0.8990

# %%
save_outputs_to_file(outputs_after, cosine_similarities_after, "after_finetuning.csv", preds=preds)

# %% [markdown]
# ## Optional: save/load model to/from Huggingface hub
#
# TODO: look at this later https://gist.github.com/younesbelkada/89fd3984a2992fdbb408fa8e3bf44101

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.22.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.2.2)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.push_to_hub("llama2-qlora-finetuned-puns-v0")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-32-3e59b846b1cd> in <cell line: 1>()
# ----> 1 model.push_to_hub("llama2-qlora-finetuned-puns-v0")
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in push_to_hub(self, repo_id, use_temp_dir, commit_message, private, use_auth_token, max_shard_size, create_pr, safe_serialization, **deprecated_kwargs)
#     812
#     813             # Save all files.
# --> 814             self.save_pretrained(work_dir, max_shard_size=max_shard_size, safe_serialization=safe_serialization)
#     815
#     816             return self._upload_modified_files(
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, **kwargs)
#    1713
#    1714         if getattr(self, "is_loaded_in_4bit", False):
# -> 1715             raise NotImplementedError(
#    1716                 "You are calling `save_pretrained` on a 4-bit converted model. This is currently not supported"
#    1717             )
#
# NotImplementedError: You are calling `save_pretrained` on a 4-bit converted model. This is currently not supported
